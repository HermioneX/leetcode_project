# %%
import pandas as pd

# %%
import numpy as np

# %%
print('PPKum!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
# Out:
# PPKum!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ## PPKun 大笨蛋

# %% [markdown]
# >> PPkun

# %%
x = np.arange(12)
y = np.sin(x)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
